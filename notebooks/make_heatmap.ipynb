# %%
import sys
sys.path.insert(0, '..')
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import colormaps
from src.data_constants import master_df_cleaned
from src.define_functions import *

# %%
sns.heatmap(master_df_cleaned[['volt','rotate', 'pressure', 'vibration', 'future_fail']].corr(),
            annot=False,cmap = 'plasma',
            fmt='0.2f')
# Out:
# <Axes: >
